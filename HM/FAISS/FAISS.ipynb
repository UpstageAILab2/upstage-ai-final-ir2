# %%
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma, FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.document_loaders.base import BaseLoader
from langchain.schema import Document
import json
import re
import numpy as np
from typing import List
from langchain.text_splitter import TextSplitter
from langchain_experimental.text_splitter import SemanticChunker
from dotenv import load_dotenv
import os
import pickle
from langchain_community.vectorstores import FAISS
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from langchain.chains.query_constructor.base import AttributeInfo, get_query_constructor_prompt
from langchain.retrievers.self_query.base import SelfQueryRetriever

# %%
load_dotenv() 
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
class JSONLLoader(BaseLoader):
    def __init__(self, file_path: str):
        self.file_path = file_path

    def load(self):
        documents = []
        seq_num = 1
        
        with open(self.file_path, 'r', encoding='utf-8') as file:
            for line in file:
                data = json.loads(line)
                doc = Document(
                    page_content=data['content'],
                    metadata={
                        'docid': data['docid'],
                        'src': data.get('src', ''),  # 'src' 필드가 없을 경우 빈 문자열 사용
                        'source': self.file_path,
                        'seq_num': seq_num,
                    }
                )
                documents.append(doc)
                seq_num += 1
        
        return documents

file_path = "/data/ephemeral/home/upstage-ai-final-ir2/HM/data/documents.jsonl"
loader = JSONLLoader(file_path)
documents = loader.load()

print(f"문서의 수: {len(documents)}")
# Out:
# 문서의 수: 4272

# %%
vectorstore = FAISS.from_documents(documents=documents, embedding=OpenAIEmbeddings())

# %%
# OpenAI LLM 초기화 
llm = OpenAI(temperature=0)

# %%
# 유사도 검색 테스트 
query = "나무의 분류에 대해 조사해 보기 위한 방법은?"

# %%
# Standalone Query Generator 프롬프트 템플릿
standalone_query_prompt = PromptTemplate(
    input_variables=["question"],
    template="""질문 query를 요약하려고 합니다. 핵심내용을 포함한 주제를 출력해주세요. 하나의 구문으로 출력해주세요. 
    아래는 예시입니다. 
    
    원래의 질문: "금성이 밝게 보이는 이유가 뭐야?"
    생성할 standalone_query: "금성 밝기 원인"

    원래의 질문: {question}
    독립적인 질문:
    """
)

# Standalone Query Generator 체인 생성
standalone_query_chain = LLMChain(llm=llm, prompt=standalone_query_prompt)

# Standalone Query 생성
standalone_query = standalone_query_chain.run(query)

print(f"Original Query: {query}")
print(f"Standalone Query: {standalone_query}")
# Out:
# Original Query: 나무의 분류에 대해 조사해 보기 위한 방법은?
# Standalone Query:
#     나무 분류 조사 방법

# %%
# K개만 검색하여 결과를 반환
K = 3
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": K})
search_result = retriever.get_relevant_documents(standalone_query)

# 결과 출력
for i, doc in enumerate(search_result, 1):
    print(f"\n문서 {i}:")
    print(f"내용: {doc.page_content[:100]}...")  # 처음 100자만 출력
    print(f"메타데이터: {doc.metadata}")
    print("---")
# Out:
# 문서 1:
# 내용: 한 학생이 다양한 종류의 나무를 조사하고 있습니다. 이 학생은 성장 속도, 온도 범위, 크기가 비슷한 두 나무를 발견했습니다. 그러나 이 두 나무의 잎과 꽃은 서로 다릅니다. 이러...
# 메타데이터: {'docid': 'c63b9e3a-716f-423a-9c9b-0bcaa1b9f35d', 'src': 'ko_ai2_arc__ARC_Challenge__test', 'source': '/data/ephemeral/home/upstage-ai-final-ir2/HM/data/documents.jsonl', 'seq_num': 2199}
# ---
#
# 문서 2:
# 내용: 고든 여사의 수업은 자연과학에 관한 것입니다. 이 수업에서는 단풍나무에 대해 공부합니다. 단풍나무는 가을에 아름다운 빨간색으로 변하는 나무로 유명합니다. 학생들은 이 나무의 특성을...
# 메타데이터: {'docid': 'b730a81a-3903-42ca-9633-88b0ebb9eb42', 'src': 'ko_ai2_arc__ARC_Challenge__train', 'source': '/data/ephemeral/home/upstage-ai-final-ir2/HM/data/documents.jsonl', 'seq_num': 474}
# ---
#
# 문서 3:
# 내용: 학생이 다른 토양 유형에서 식물의 성장을 연구했습니다. 연구에서는 날짜와 식물의 높이, 그리고 토양 유형을 기록하였습니다. 이러한 데이터를 정리하는 가장 좋은 방법은 날짜와 식물의...
# 메타데이터: {'docid': 'a153c822-be9f-4346-8558-34365ed7b4f0', 'src': 'ko_ai2_arc__ARC_Challenge__test', 'source': '/data/ephemeral/home/upstage-ai-final-ir2/HM/data/documents.jsonl', 'seq_num': 1414}
# ---

# %%
science_check_prompt = PromptTemplate(
    input_variables=["question"],
    template="""
다음 질문이 지식을 묻는 내용인지 판단해주세요:

질문: {question}

이 질문이 상식이나 지식을 묻는 것(물리, 화학, 생물, 지구과학, 천문학, 컴퓨터공학, 소프트웨어 등)이라면 "True"라고만 답변하고, 그렇지 않다면 "False"라고만 답변해주세요.

예시:
1. "물의 화학식은 무엇인가요?" -> True
2. "지구의 자전 주기는 얼마인가요?" -> True
3. "오늘 기분이 아주 좋아" -> False
4. "너는 어쩜 모르는게 없구나?" -> False
5. "니가 대답을 잘해줘서 너무 고마워!" -> False
6. "v파이

답변:
"""
)

science_check_chain = LLMChain(llm=llm, prompt=science_check_prompt)

# %%
def is_science_related(query):
    science_check_result = science_check_chain.run(query).strip().lower()
    return science_check_result == "true"

# %%
def answer_question(query):
    # 과학 상식 관련 질문인지 확인
    if not is_science_related(query):
        return {
            "answer": "",
            "standalone_query": "",
            "is_science_related": False,
            "topk": [],
            "references": []
        }


    # Standalone Query 생성
    standalone_query = standalone_query_chain.run(query)

    # standalone_query가 과학 상식과 관련 있는지 확인
    standalone_query_science_related = is_science_related(standalone_query)

    # 검색 수행 (K개 검색)
    K = 3
    retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": K})
    search_result = retriever.get_relevant_documents(standalone_query)

    # RAG 프롬프트 가져오기
    rag_prompt = hub.pull("rlm/rag-prompt")

    # 첫 번째 문서의 내용만 사용
    context = search_result[0].page_content if search_result else ""

    # LLM 체인 생성
    llm = OpenAI(temperature=0)
    rag_chain = LLMChain(llm=llm, prompt=rag_prompt)

    # 답변 생성 (첫 번째 문서만 참고)
    answer = rag_chain.run(context=context, question=query)
    
    standalone_query = standalone_query_chain.run(query).strip('"')  # 따옴표 제거

    # topk 및 references 정보 추출
    topk = [doc.metadata.get('docid') for doc in search_result]
    
    # 이미 검색된 문서의 내용을 사용
    references = [
        {
            "score": doc.metadata.get('score', 0),
            "content": doc.page_content
        }
        for doc in search_result
    ]


    return {
        "standalone_query": standalone_query,
        "is_science_related": standalone_query_science_related,
        "topk": topk,
        "answer": answer,
        "references": references
    }

# %%
def eval_rag(eval_filename, output_filename):
    with open(eval_filename) as f, open(output_filename, "w") as of:
        idx = 0
        for line in f:
            j = json.loads(line)
            print(f'Test {idx}\nQuestion: {j["msg"]}')
            response = answer_question(j["msg"])
            print(f'Answer: {response["answer"]}')
            print(f'Standalone Query: {response["standalone_query"]}')
            print(f'Is Science Related: {response["is_science_related"]}\n')

            output = {
                "eval_id": j["eval_id"],
                "standalone_query": response["standalone_query"],
                # "is_science_related": response["is_science_related"],
                "topk": response["topk"],
                "answer": response["answer"],
                "references": response["references"]
            }
            of.write(f'{json.dumps(output, ensure_ascii=False)}\n')
            idx += 1

# %%
eval_rag("/data/ephemeral/home/upstage-ai-final-ir2/upstage-ai-final-ir2/HM/data/eval.jsonl", "sample_submission_8.csv")
# Out:
# Test 0
# Question: [{'role': 'user', 'content': '나무의 분류에 대해 조사해 보기 위한 방법은?'}]
# Answer:  이 학생은 나무의 분류를 위해 성장 속도, 온도 범위, 크기, 잎과 꽃의 유사성 등을 고려하고 있습니다. 이러한 특징들은 나무의 속을 파악하는 데 중요한 역할을 합니다. 나무의 분류는 생물 분류학에서 중요한 기준 중 하나이며, 이 학생의 조사 결과는 나무의 분류와 관련된 중요한 정보를 제공할 수 있습니다.
# Standalone Query: 나무 분류 조사 방법
# Is Science Related: False
#
# Test 1
# Question: [{'role': 'user', 'content': '각 나라에서의 공교육 지출 현황에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 2
# Question: [{'role': 'user', 'content': '기억 상실증 걸리면 너무 무섭겠다.'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '어떤 원인 때문에 발생하는지 궁금해.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 3
# Question: [{'role': 'user', 'content': '통학 버스의 가치에 대해 말해줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 4
# Question: [{'role': 'user', 'content': 'Dmitri Ivanovsky가 누구야?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 5
# Question: [{'role': 'user', 'content': '피임을 하기 위한 방법중 약으로 처리하는 방법은 쓸만한가?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 6
# Question: [{'role': 'user', 'content': '헬륨이 다른 원소들과 반응을 잘 안하는 이유는?'}]
# Answer:  헬륨은 다른 원소들과 반응을 잘 안하는 이유는 그의 전자 구조 때문입니다. 헬륨은 전자 껍질이 완전히 차 있기 때문에 다른 원소들과 반응할 수 있는 자리가 없습니다. 따라서, 헬륨은 다른 원소들과 반응하지 않고 안정한 상태를 유지합니다.
# Standalone Query: 헬륨의 반응성 부족 원인
# Is Science Related: True
#
# Test 7
# Question: [{'role': 'user', 'content': '문맹 비율이 사회 발전에 미치는 영향은?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 8
# Question: [{'role': 'user', 'content': '이란 콘트라 사건이 뭐야'}, {'role': 'assistant', 'content': '이란-콘트라 사건은 로널드 레이건 집권기인 1986년에 레이건 행정부와 CIA가 적성국이었던 이란에게 무기를 몰래 수출한 대금으로 니카라과의 우익 성향 반군 콘트라를 지원하면서 동시에 반군으로부터 마약을 사들인 후 미국에 판매하다가 발각되어 큰 파장을 일으킨 사건입니다.'}, {'role': 'user', 'content': '이 사건이 미국 정치에 미친 영향은?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 9
# Question: [{'role': 'user', 'content': '자기장이 얼마나 센지 표현하는 방식은?'}]
# Answer:  자기장의 강도는 온도와 함께 변화할 수 있으며, 이는 자기장이 핵 자체에 가하는 영향을 나타내는 중요한 지표입니다. 이러한 계산은 자기 공명 이미징 (MRI)과 같은 응용 분야에서 중요한 역할을 합니다. 따라서 자기장의 강도를 나타내는 방식은 온도와 핵의 평형 분극을 계산하는 것으로 표현될 수 있습니다.
# Standalone Query: 자기장 강도 표현 방식
# Is Science Related: True
#
# Test 10
# Question: [{'role': 'user', 'content': '피를 맑게 하고 몸 속의 노폐물을 없애는 역할을 하는 기관은?'}]
# Answer:  소화계
# Standalone Query: 피 정화 기관
# Is Science Related: False
#
# Test 11
# Question: [{'role': 'user', 'content': '글리코겐의 분해는 인체에서 왜 필요한가?'}]
# Answer:  글리코겐의 분해는 근육 세포에서 에너지 생산과 근육 기능을 유지하는 데 필수적인 과정입니다. 이 과정은 운동이나 기타 활동을 할 때 근육에서 사용되는 주요한 에너지원이 됩니다. 따라서, 인체에서 글리코겐의 분해는 운동 능력을 유지하는 데 중요한 역할을 합니다.
# Standalone Query: 글리코겐 분해의 인체 내 필요성
# Is Science Related: True
#
# Test 12
# Question: [{'role': 'user', 'content': '빗방울이 점점 커지게 되는 요인은?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 13
# Question: [{'role': 'user', 'content': '기체의 부피나 형태가 왜 일정하지 않을까?'}]
# Answer:  신체적 변화는 개인마다 다르게 나타날 수 있으며, 이는 개인의 생리적 특성과 환경 요인에 따라 달라질 수 있다. 따라서, 신체적 변화에 대한 이해는 개인의 건강과 웰빙을 유지하는 데 중요한 역할을 할 수 있다.
# Standalone Query: 기체 부피 형태 변화 원인
# Is Science Related: True
#
# Test 14
# Question: [{'role': 'user', 'content': '식물이 빛을 에너지로 변환하는 과정에 대해 설명해줘.'}]
# Answer:  태양에서 나오는 에너지는 초록 식물들이 흡수하여 광합성을 통해 화학 에너지로 변환됩니다. 이 화학 에너지는 다른 생물들에게 전달되어 다양한 영양 단계의 생물들이 사용할 수 있습니다. 영양 단계가 증가함에 따라 사용 가능한 에너지가 감소하게 됩니다.
# Standalone Query: 식물의 빛 에너지 변환 과정 설명
# Is Science Related: True
#
# Test 15
# Question: [{'role': 'user', 'content': '직류와 교류 전류의 차이에 대해 알려줘.'}]
# Answer:  직류와 교류 전류의 가장 큰 차이점은 전류의 방향이 일정하게 유지되는지 주기적으로 변화하는지에 있다. 직류는 전하가 한 방향으로 흐르며, 교류는 전하가 주기적으로 방향을 바꾼다. 이러한 차이점은 전기 회로의 용도와 특성에 따라 선택되고 활용된다.
# Standalone Query: 직류와 교류 전류의 차이점
# Is Science Related: True
#
# Test 16
# Question: [{'role': 'user', 'content': '기름과 물이 섞여 있을 수 있나?'}]
# Answer:  물은 실온에서 기체인 두 가지 원소로 만들 수 없는 기체가 아닌 화합물입니다. 따라서, 물과 기름이 섞여 있을 수 있습니다.
# Standalone Query: 기름과 물의 혼합 가능성
# Is Science Related: True
#
# Test 17
# Question: [{'role': 'user', 'content': '인간이 2세를 생산할 때 DNA의 결합 과정에 대히 설명해줘.'}]
# Answer:  남성과 여성의 생식세포가 결합할 때, 염색체의 수는 두 배가 되며, 이는 염색체의 유전 정보를 조합하여 새로운 개체를 형성하는 과정입니다. 염색체는 DNA를 포함하고 있으며, DNA는 유전 정보를 담고 있는 분자입니다. 따라서, 자손은 부모의 유전 정보를 조합하여 새로운 개체를 형성하게 됩니다.
# Standalone Query: 인간의 DNA 결합 과정
# Is Science Related: True
#
# Test 18
# Question: [{'role': 'user', 'content': '금성에서 달이 어떻게 보일까?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 19
# Question: [{'role': 'user', 'content': '차량의 연비가 좋아질때 나타나는 긍정적인 효과는?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 20
# Question: [{'role': 'user', 'content': '혼합물의 특성에 대해 알려줘.'}]
# Answer:  이 혼합물은 땅콩, 해바라기 씨, 건포도, 아몬드, 초콜릿 조각으로 구성되어 있으며, 각각의 성분은 독립적으로 존재할 수 있지만, 혼합물로 합쳐지면 각 성분은 여전히 그들의 고유한 특성을 가지고 있습니다. 따라서, 이 혼합물은 구성 요소가 원래의 성질을 유지하기 때문에 혼합물로서의 특성을 가지고 있습니다.
# Standalone Query: 혼합물 특성
# Is Science Related: True
#
# Test 21
# Question: [{'role': 'user', 'content': '요새 너무 힘들다.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 22
# Question: [{'role': 'user', 'content': '세제의 거품이 만들어지는 원리는?'}]
# Answer:  세제의 거품이 만들어지는 원리는 화학 반응을 통해 단순한 유기 화합물이 서로 상호 작용하여 더 복잡한 구조를 형성하는 과정에서 자기 복제 구조가 형성되어 생명체의 기반이 되는 것으로 추정됩니다. 이는 생명의 기원에 대한 현재의 주류 이론 중 하나로, 지구에서 생명이 어떻게 발달해왔는지를 이해하는 데 중요한 역할을 합니다. 그러나 정확한 원리는 아직 밝혀지지 않았습니다.
# Standalone Query: 세제 거품 생성 원리
# Is Science Related: True
#
# Test 23
# Question: [{'role': 'user', 'content': '나무가 생태계에서 하는 역할에 대해 설명해줘.'}]
# Answer:  나무는 식물의 중요한 부분으로, 지지력을 제공하고 물과 영양분을 공급하며, 열과 수분을 조절하여 생존에 필수적인 역할을 합니다. 또한 광합성을 통해 영양분을 생산하고, 식물의 구조를 유지하고 세포들이 통신하고 협력할 수 있도록 돕는 역할도 합니다. 따라서 나무는 식물의 생존과 번식에 있어서 매우 중요한 역할을 수행합니다.
# Standalone Query: 나무의 생태계 역할 설명
# Is Science Related: True
#
# Test 24
# Question: [{'role': 'user', 'content': '전류의 흐름을 극대화 하려면 배터리와 저항을 어떻게 연결해야 하나?'}]
# Answer:  배터리와 저항기를 직렬로 연결하면 가장 큰 전류를 만들 수 있습니다. 직렬 연결은 배터리와 저항기가 한 줄로 연결되는 구성을 말합니다. 따라서, 저항이 직렬로 배치된 고전압 배터리를 사용하면 가장 큰 전류를 만들 수 있는 회로를 만들 수 있습니다.
# Standalone Query: 전류 극대화를 위한 배터리와 저항 연결 방법
# Is Science Related: False
#
# Test 25
# Question: [{'role': 'user', 'content': '식물이 높이 자랄 수 있게 하는 메커니즘이 궁금해.'}]
# Answer:  식물의 성장을 관찰하고 측정하는 것은 식물이 얼마나 자랐는지 기록하는 것입니다. 이를 통해 식물의 성장 속도를 파악하고 변화를 추적할 수 있습니다. 이를 통해 식물의 건강 상태와 환경 요인에 대한 이해를 높일 수 있습니다.
# Standalone Query: 식물의 성장을 도와주는 메커니즘
# Is Science Related: True
#
# Test 26
# Question: [{'role': 'user', 'content': '달을 보면 항상 같은 면만 보이더라구'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유가 뭐야?'}]
# Answer:  달은 지구 주위를 공전하면서 동시에 자전을 합니다. 이때 달의 자전 주기와 궤도 주기가 정확히 일치하면서, 항상 같은 면을 우리에게 보여줍니다. 이러한 현상을 '달의 결합 자전'이라고 합니다.
# Standalone Query: 달의 항상 같은 면이 보이는 이유
# Is Science Related: True
#
# Test 27
# Question: [{'role': 'user', 'content': '식초와 베이킹 소다를 섞어주면 어떤 일이 일어나?'}]
# Answer:  식초와 베이킹 소다를 섞으면 화학 반응이 일어나고 소량의 기체가 생성됩니다. 생성된 기체는 혼합 용기 안에 갇혀 있으며, 최종 생성물의 질량은 원래 식초와 베이킹 소다의 질량에 생성된 기체의 질량을 더한 값인 105그램이 됩니다.
# Standalone Query: 식초와 베이킹 소다의 혼합효과
# Is Science Related: True
#
# Test 28
# Question: [{'role': 'user', 'content': '세균이 나쁜줄말 알았는데 그게 아니야?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그럼 순기능에 대해 알려줄래?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 29
# Question: [{'role': 'user', 'content': '오토마톤의 특징에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 30
# Question: [{'role': 'user', 'content': '다양한 책을 catalog화 하는 코드에서 class 정의 방법 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 31
# Question: [{'role': 'user', 'content': '전구가 병렬로 연결될 때 전류가 줄어드는 원인은?'}]
# Answer:  전구가 병렬로 연결될 때 전류가 줄어드는 원인은 각 전구의 전류가 독립적으로 흐르기 때문입니다. 따라서 한 전구의 전류가 증가하더라도 다른 전구의 전류는 변하지 않습니다. 하지만 전구의 전류는 전압과 저항에 따라 결정되기 때문에, 전압과 저항에 대한 정보가 주어지지 않으면 정확한 대답을 할 수 없습니다.
# Standalone Query: 전구 병렬 연결시 전류 감소 원인
# Is Science Related: True
#
# Test 32
# Question: [{'role': 'user', 'content': '물속에서 침전이 발생하는 원리에 대해 알려줘.'}]
# Answer:  물속에서 침전이 발생하는 원리는 유속이 감소하면 물 속의 입자들이 더 오랫동안 머무르게 되므로, 입자들이 침전할 가능성이 높아지기 때문입니다. 이는 특히 물 속에 포함된 흙, 모래, 부유물질 등이 침전하여 강물이나 하천의 바닥에 쌓이는 현상으로 나타납니다. 따라서, 유속이 감소하면 흐름 내 물질 침전이 증가할 가능성이 있습니다.
# Standalone Query: 물속에서 침전이 발생하는 원리
# Is Science Related: True
#
# Test 33
# Question: [{'role': 'user', 'content': '화산 폭발이 발생한 후 새로운 생물 군집이 생겨나는 것을 무엇이라 부르나?'}]
# Answer:  1차 승계
# Standalone Query: 화산 폭발 후 생물 군집 생성
# Is Science Related: True
#
# Test 34
# Question: [{'role': 'user', 'content': '축전기를 병렬로 이어주면 전체 용량이 어떻게 되는가?'}]
# Answer:  전원의 전류는 증가한다. 이는 전류의 분배 법칙에 따라 각 램프에 동일한 전압이 인가되기 때문이다. 따라서, 병렬로 연결된 램프의 개수가 늘어남에 따라 전원의 전류는 증가한다고 할 수 있다.
# Standalone Query: 축전기 병렬 연결 시 전체 용량
# Is Science Related: True
#
# Test 35
# Question: [{'role': 'user', 'content': '정육면체가 가라앉지 않고 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은?'}]
# Answer:  정육면체가 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은 물체의 밀도를 구한 후, 물의 밀도와 비교하여 물체의 부피를 구하는 것입니다. 이를 위해서는 물체의 무게를 측정하고, 물의 밀도를 알아야 합니다. 그리고 물체의 부피를 구할 수 있습니다.
# Standalone Query: 물 위에 떠 있는 정육면체의 수면 윗부분 부피 구하는 방법
# Is Science Related: True
#
# Test 36
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 너무 신나!'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 37
# Question: [{'role': 'user', 'content': '건설 현장에서 망치로 벽을 치는 이유는?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 38
# Question: [{'role': 'user', 'content': '차량의 매연이 발생하지 않게 만드는 장치가 무엇인가?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 39
# Question: [{'role': 'user', 'content': 'python에서 lambda 함수를 언제 사용할 수 있어?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 40
# Question: [{'role': 'user', 'content': '강이나 바다의 물이 증발하는 가장 중요한 원인은?'}]
# Answer:  바다의 넓은 면적과 태양의 열을 흡수하는 역할로 인해 바다에서 많은 양의 물이 증발합니다. 이는 바다가 지구의 물 가운데 약 97퍼센트를 차지하고 있기 때문입니다. 따라서 대부분의 증발은 바다에서 일어나게 됩니다.
# Standalone Query: 강이나 바다의 물 증발 원인
# Is Science Related: True
#
# Test 41
# Question: [{'role': 'user', 'content': '남녀 관계에서 정서적인 행동이 왜 중요해?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 42
# Question: [{'role': 'user', 'content': 'DNA 조각들이 서로 결합되도록 돕는 것은?'}]
# Answer:  DNA 중합효소는 보완적인 뉴클레오티드를 추가하여 새로운 DNA를 생성하는 역할을 합니다. 이 과정에서 중합효소는 A와 T 염기를 비율에 맞게 추가하여 새로운 DNA 가닥의 A:T 비율을 조절합니다. 따라서, 새로 합성된 DNA 가닥의 A:T 비율은 2:03이 됩니다.
# Standalone Query: DNA 결합 도움 주는 것
# Is Science Related: False
#
# Test 43
# Question: [{'role': 'user', 'content': '해가 뜨는 현상이 지구의 자전과 관련있어?'}]
# Answer:  지구의 자전과 공전은 매일 해가 뜨고 지는 현상을 발생시키는 주요한 원인입니다. 자전은 지구가 자체적으로 돌아가는 운동이며, 공전은 태양 주위를 돌면서 한 해를 완성하는 운동입니다. 이 두 가지 운동이 결합하여 매일 해가 뜨고 지는 현상이 발생합니다.
# Standalone Query: 해가 뜨는 현상과 지구의 자전의 관계
# Is Science Related: True
#
# Test 44
# Question: [{'role': 'user', 'content': '두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있다는 것을 어떻게 알 수 있나요?'}]
# Answer:  화학 물질이 분리되지 않고 독립된 형태로 존재하는 것을 통해 두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있다는 것을 알 수 있습니다. 이는 원소라는 것을 가장 잘 설명합니다. 따라서, 이 화학 물질은 다른 화학 물질로 분리될 수 없다는 것을 의미합니다.
# Standalone Query: 물질의 분자구조와 화학적 성분을 어떻게 구분할 수 있나요?
# Is Science Related: True
#
# Test 45
# Question: [{'role': 'user', 'content': '수성이 뜨거운 이유는?'}]
# Answer:  수성은 태양에 가장 가까운 행성이기 때문에 태양으로부터 많은 열을 받게 됩니다. 그러나 수성에는 대기가 없기 때문에 열을 효과적으로 분산시키지 못하고, 따라서 표면 온도가 극단적으로 변동하게 됩니다. 이러한 이유로 수성은 온도 변화가 매우 큰 행성으로 알려져 있습니다.
# Standalone Query: 수성 뜨거운 이유
# Is Science Related: True
#
# Test 46
# Question: [{'role': 'user', 'content': '하구 퇴적지의 기능에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 47
# Question: [{'role': 'user', 'content': '디엔에이에서 퓨린과 피리미딘은 어떤 비율로 존재하는가?'}]
# Answer:  푸린과 피리미딘은 항상 1:1의 비율로 존재합니다. 이는 DNA 분자의 구조와 기능을 유지하는 데 중요한 역할을 합니다. 따라서 이중 가닥 DNA 분자에서 푸린과 피리미딘의 비율은 항상 1:1입니다.
# Standalone Query: 디엔에이에서 퓨린과 피리미딘의 비율은 어떻게 되나요?
# Is Science Related: False
#
# Test 48
# Question: [{'role': 'user', 'content': 'interferon의 역할에 대해 알려줘.'}]
# Answer:  인터페론은 면역 시스템에서 바이러스나 다른 병원체에 감염된 세포에서 생성되어 인접한 세포에 경고 신호를 보내 바이러스의 전파를 막는 역할을 합니다. 또한 세포의 면역 반응을 강화시키고 면역 시스템이 병원체에 대항할 수 있도록 돕습니다. 이러한 방식으로 인터페론은 매우 특별한 방어 메커니즘으로 작동합니다.
# Standalone Query: interferon의 역할
# Is Science Related: True
#
# Test 49
# Question: [{'role': 'user', 'content': '하나의 유전자에서 여러가지 단백질이 만들어질 수 있는 원인은?'}]
# Answer:  선택적 RNA 이어맞추기는 여러 mRNA를 생성하는 과정으로, 이를 통해 다양한 단백질이 생성될 수 있습니다. 이는 유전자의 정보를 효율적으로 활용하여 여러 다른 기능을 수행하는 단백질을 만들어낼 수 있는 메커니즘입니다. 따라서 동일한 유전자에서 여러 다른 단백질이 생성될 수 있는 것입니다.
# Standalone Query: 유전자에서 다양한 단백질 생성 원인
# Is Science Related: True
#
# Test 50
# Question: [{'role': 'user', 'content': '질산을 통한 염화물 침전시 염소의 비율을 구하는 방법은?'}]
# Answer:  염소 비율 = (0.107g / 2.35g) x 100 = 4.60%
# Standalone Query: 질산 염화물 침전 염소 비율 구하는 방법
# Is Science Related: True
#
# Test 51
# Question: [{'role': 'user', 'content': '이제 그만 얘기해!'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 52
# Question: [{'role': 'user', 'content': '오늘 너무 즐거웠다!'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 53
# Question: [{'role': 'user', 'content': '우울한데 신나는 얘기 좀 해줘!'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 54
# Question: [{'role': 'user', 'content': '연구자가 갖추어야 할 태도와 자세가 뭘까?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 55
# Question: [{'role': 'user', 'content': '나이가 들수록 시간이 더 빨리 가는 것 처럼 느끼게 되는 원인은?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 56
# Question: [{'role': 'user', 'content': '퇴직한 사람들에게 사회 보장은 어떤 의미인가?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 57
# Question: [{'role': 'user', 'content': '사람이나 물체가 지구 위에서 땅속으로 꺼지거나 바깥으로 튕겨나가지 않고 가만히 서 있을 수 있잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '그 이유를 힘의 원리로 설명해줘.'}]
# Answer:  풀이 자라서 흙을 고정하는 것이 힘의 원리입니다. 풀의 뿌리가 흙에 꽂혀 있기 때문에 비가 내려와도 흙이 씻겨 내려가지 않게 되었습니다. 이로 인해 집 쪽으로 흘러들어오는 흙의 양이 줄어들게 되었습니다.
# Standalone Query: 땅속으로 꺼지거나 바깥으로 튕겨나가지 않는 이유
# Is Science Related: True
#
# Test 58
# Question: [{'role': 'user', 'content': '씨앗의 기능에 대해 자세히 알려줘?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 59
# Question: [{'role': 'user', 'content': '친환경 재생 가능 재료가 어떤것들이 있나?'}]
# Answer:  재생 가능 자원으로는 오랜 세월 동안 사용할 수 있는 자원이 있으며, 이는 자원의 지속적인 공급을 보장하고 우리의 에너지 소비를 지속 가능한 수준으로 유지할 수 있습니다. 또한 재생 가능 자원은 환경에 친숙하며, 이는 이산화탄소 배출을 줄이고 대기 오염을 감소시킴으로써 지구 온난화와 대기 오염 문제를 완화하는 데 도움이 됩니다. 마지막으로 재생 가능 자원은 경제적으로 이점이 있으며, 이는 신규 산업을 육성하고 일자리를 창출함으로써 경제 성장을 촉진하는 데 도움이 됩니다.
# Standalone Query: 친환경 재생 가능 재료
# Is Science Related: False
#
# Test 60
# Question: [{'role': 'user', 'content': '남미의 라틴 역사에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 61
# Question: [{'role': 'user', 'content': '원자의 내부 구조에 대해 설명해줘.'}]
# Answer:  원자는 핵과 전자로 구성되어 있으며, 전자는 핵 주변의 궤도를 돌면서 음전하를 가지고 있습니다. 전자는 원자의 전하를 중립화시키는 역할을 하며, 원자의 화학적 특성과 반응성을 결정짓는 중요한 요소입니다. 따라서, 전자는 원자의 구성과 성질을 이해하는데 핵심적인 역할을 합니다.
# Standalone Query: 원자 내부 구조 설명
# Is Science Related: True
#
# Test 62
# Question: [{'role': 'user', 'content': '난관의 기능에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 63
# Question: [{'role': 'user', 'content': '공기의 온도가 기후에 미치는 영향은?'}]
# Answer:  공기 온도는 태양 에너지의 흡수와 방출에 직접적인 영향을 미치며, 대기의 열전달과 대류에도 영향을 줍니다. 따라서 공기 온도는 태양 에너지의 지구 대기에 대한 영향을 결정하는 중요한 척도입니다.
# Standalone Query: 기후에 영향을 미치는 공기 온도의 역할
# Is Science Related: True
#
# Test 64
# Question: [{'role': 'user', 'content': '안녕 반갑다'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 65
# Question: [{'role': 'user', 'content': '평균을 구하는 코드를 작성중이야.'}, {'role': 'assistant', 'content': '네 무엇을 도와드릴까요?'}, {'role': 'user', 'content': '예외처리가 필요한 경우를 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 66
# Question: [{'role': 'user', 'content': '소프트웨어 개발이 사람의 편향없이 이루어질 수 있나?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 67
# Question: [{'role': 'user', 'content': '전체 인구에서 특정 유전자의 비율이 변하지 않고 유지되는 상태를 뭐라고 해?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 68
# Question: [{'role': 'user', 'content': '지구가 생겨난지 얼마나 오래 되었는지 확인하는 방법은?'}]
# Answer:  지구가 생겨난지 얼마나 오래 되었는지 확인하는 방법은 지구의 자전과 공전을 관찰하는 것입니다. 지구의 자전은 하루 동안 한 바퀴를 돌기 때문에 매일 해가 뜨고 지는 것을 관찰할 수 있습니다. 또한, 지구의 공전은 약 365일이 소요되기 때문에 한 해 동안 해가 뜨고 지는 사건이 반복됩니다.
# Standalone Query: 지구 생성 시간 확인 방법
# Is Science Related: True
#
# Test 69
# Question: [{'role': 'user', 'content': '성적인 자극이 발생하는 과정에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 70
# Question: [{'role': 'user', 'content': '전선 주위로 흐르는 자기장의 모습은 어떻게 보이나?'}]
# Answer:  자외선은 파장이 대략 6 x 10^-8m인 빛으로, 주파수는 5 x 10^15Hz입니다. 이는 우리가 보통 인식할 수 없는 파장을 가지고 있으며, 태양으로부터 발생하여 우리 피부에 유해한 영향을 줄 수 있습니다. 따라서 자외선 차단제를 사용하여 피부를 보호하는 것이 중요합니다.
# Standalone Query: 전선 주위 자기장 모습
# Is Science Related: True
#
# Test 71
# Question: [{'role': 'user', 'content': '간헐적으로 높은 강도의 운동을 하면 어떤 효과가 있나요?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 72
# Question: [{'role': 'user', 'content': '아세틸 콜린의 역할이 뭐야?'}]
# Answer:  아세틸콜린은 운동 종말판에서 신경과 근육 사이의 연결을 강화하고, 근육 수축을 유발하는 역할을 합니다. 이는 운동을 원활하게 수행하는 데 중요한 역할을 합니다. 따라서, 아세틸콜린은 운동 종말판에서 핵심적인 역할을 수행하는 물질입니다.
# Standalone Query: 아세틸 콜린의 역할
# Is Science Related: True
#
# Test 73
# Question: [{'role': 'user', 'content': '디엔에이와 단백질의 관계와 역할에 대해 설명해줘.'}]
# Answer:  디엔에이는 DNA의 구조와 기능을 연구하는 데에 있어서 핵심적인 역할을 수행하며, 아데닌과 티민의 상호작용에 대한 연구는 생명 과학 분야에서 매우 중요하다. 아데닌은 DNA의 구성 요소 중 하나로, DNA 더블 헬릭스에서 티민과 결합하여 염기 서열을 형성한다. 이러한 아데닌-티민 쌍은 DNA의 안정성과 유전 정보 전달에 중요한 역할을 한다.
# Standalone Query: 디엔에이와 단백질의 관계와 역할
# Is Science Related: True
#
# Test 74
# Question: [{'role': 'user', 'content': '자전축이 기후에 미치는 영향은?'}]
# Answer:  기후 변화는 식량 생산에 부정적인 영향을 미치며, 식량 가격 상승과 식량 안보에 직접적인 영향을 미칠 수 있습니다. 따라서, 기후 변화에 대한 대비책 마련과 지속 가능한 농업 방법과 식량 생산 기술의 개발이 필요합니다. 또한, 국제적인 협력과 지원을 통해 개발 도상국의 식량 안보를 지원하는 것이 중요합니다.
# Standalone Query: 자전축 기후 영향
# Is Science Related: True
#
# Test 75
# Question: [{'role': 'user', 'content': '여행을 통해 얻을 수 있는 좋은 점들이 뭐가 있어?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 76
# Question: [{'role': 'user', 'content': '은하들이 점점 멀어지고 있다던데 맞아?'}, {'role': 'assistant', 'content': '네 맞아요.'}, {'role': 'user', 'content': '어떤 물리적인 현상을 보고 그걸 알게 되었어?'}]
# Answer:  물리적 변화는 우리 주변에서 빈번하게 일어나는 현상이며, 망치를 사용하여 물체를 더 작은 조각으로 깨뜨리는 것과 물체의 운동이 그 예시입니다. 이러한 물리적 변화는 우리가 일상적으로 관찰할 수 있는 현상 중 하나입니다. 따라서, 물리적 변화는 우리가 일상적으로 경험하는 현상 중 하나입니다.
# Standalone Query: 은하들 멀어지는 물리적 현상
# Is Science Related: True
#
# Test 77
# Question: [{'role': 'user', 'content': '목성 trojan의 특징에 대해 알려줘.'}]
# Answer:  목성 trojan은 목성의 궤도를 따라 위치하고 있으며, 목성 앞뒤로 60°에 위치해 있습니다. 이 소행성은 목성과의 중력 상호작용으로 인해 안정한 궤도를 유지하고 있습니다. 이러한 특징 때문에 트로이군 소행성은 천문학적인 연구에 많은 관심을 받고 있습니다.
# Standalone Query: 목성 trojan 특징
# Is Science Related: True
#
# Test 78
# Question: [{'role': 'user', 'content': '슈퍼옥시드 디스무타아제 라는 효소에 대해 설명해줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 79
# Question: [{'role': 'user', 'content': '네바다주에 살고 있는데...'}, {'role': 'assistant', 'content': '네 그러시군요?'}, {'role': 'user', 'content': '여기 비가 많이 오지 않는 이유가 뭐야?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 80
# Question: [{'role': 'user', 'content': '어떤 물체를 매우 크게 확대해서 볼수 있는 기계는?'}]
# Answer:  바느질 기계는 매우 크게 확대해서 볼수 있는 기계는 아닙니다.
# Standalone Query: 물체 확대 기계
# Is Science Related: False
#
# Test 81
# Question: [{'role': 'user', 'content': 'merge sort 알고리즘에 대해 설명해줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 82
# Question: [{'role': 'user', 'content': '심해가 생태계에 미치는 영향은?'}]
# Answer:  인간의 개입으로 인해 생태계는 재구성되고, 이는 생태계의 단순화를 초래한다. 이러한 단순화는 다양한 종들의 수를 감소시키고, 대규모 인구의 존재를 제한한다. 따라서 교란된 생태계에서는 낮은 수의 종의 대규모 인구가 존재함을 시사한다.
# Standalone Query: 심해 생태계 영향
# Is Science Related: True
#
# Test 83
# Question: [{'role': 'user', 'content': '저항이 2배로 증가하면 전력은 어떻게 되나?'}]
# Answer:  에너지 소모 속도는 전압의 제곱에 비례하여 증가하므로, 전압이 2배로 증가하면 전력은 4배로 증가합니다.
# Standalone Query: 저항 증가에 따른 전력 변화
# Is Science Related: True
#
# Test 84
# Question: [{'role': 'user', 'content': '산에 불이 나면 동식물이 많이 죽을텐데'}, {'role': 'assistant', 'content': '네 안타까운 일입니다.'}, {'role': 'user', 'content': '불난 후에 자연의 회복 과정은 어떻게 돼?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 85
# Question: [{'role': 'user', 'content': 'DNA 분해 효소의 역할에 대해 알려줘.'}]
# Answer:  DNA 분해효소는 뉴클레오솜 이합체를 뉴클레오솜 단합체로 소화하는 과정에서 연결 DNA를 표적물로 삼습니다. 이 과정은 DNA 분해효소가 특정한 위치에서 DNA 분자를 인식하고 분해하는 과정을 포함합니다. 연결 DNA는 뉴클레오솜 이합체를 유지하는 역할을 합니다.
# Standalone Query: DNA 분해 효소의 역할
# Is Science Related: True
#
# Test 86
# Question: [{'role': 'user', 'content': '특정 농도의 황산 sample을 만드는 방법?'}]
# Answer:  4.0 M 황산 100 mL를 만들기 위해선 67.7 mL의 물과 12.0 M 황산 33.3 mL를 섞으면 됩니다. 이때 용액을 충분히 섞어야 합니다.
# Standalone Query: 황산 sample 제작 방법
# Is Science Related: True
#
# Test 87
# Question: [{'role': 'user', 'content': '달은 1년 동안 지구를 몇바퀴 도는가?'}]
# Answer:  달은 일 년에 지구를 대략 13번 공전합니다. 이는 지구의 공전 주기와는 다릅니다. 따라서, 달은 일 년에 지구를 대략 13번 공전합니다.
# Standalone Query: 달의 1년간 지구 주변 공전 횟수
# Is Science Related: True
#
# Test 88
# Question: [{'role': 'user', 'content': '개인의 생물학적, 사회적인 특성 형성에 영향을 미치는 요소에 대해 설명해줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 89
# Question: [{'role': 'user', 'content': '너는 누구야?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 90
# Question: [{'role': 'user', 'content': '지각은 주로 무엇으로 이루어져 있어?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 91
# Question: [{'role': 'user', 'content': '오세아니아 섬나라에 광견병이 있어?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 92
# Question: [{'role': 'user', 'content': '추울때 폭이 넓은 회색의 구름이 끼면 어떤 날씨가 예상되나?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 93
# Question: [{'role': 'user', 'content': '안정성이 높은 PRP를 만드는 방법에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 94
# Question: [{'role': 'user', 'content': '너 모르는 것도 있니?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 95
# Question: [{'role': 'user', 'content': '중성자의 특징에 대해 설명해줘.'}]
# Answer:  중성자는 매우 높은 밀도를 가진 천체로, 별이 폭발한 후 남은 핵물질로 이루어져 있습니다. 이러한 높은 밀도로 인해 중성자는 매우 강한 중력을 가지고 있으며, 이는 중성자의 특징 중 하나입니다. 중성자는 우주에서 매우 희귀한 천체로 알려져 있으며, 우주의 이론적인 모델링과 중력에 대한 연구에 중요한 역할을 합니다.
# Standalone Query: 중성자의 특징 설명
# Is Science Related: True
#
# Test 96
# Question: [{'role': 'user', 'content': '플랑크톤의 역할에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 97
# Question: [{'role': 'user', 'content': '기생과 공생의 차이에 대해 알려줘.'}]
# Answer:  기생과 공생은 둘 다 한 종류의 생물이 다른 종류의 생물에게서 이익을 얻는 관계이지만, 기생은 다른 생물을 해치는 반면 공생은 해치지 않습니다. 이러한 차이로 인해 기생과 공생은 서로 다른 생물학적 관계를 가지고 있습니다.
# Standalone Query: 기생과 공생의 차이점
# Is Science Related: True
#
# Test 98
# Question: [{'role': 'user', 'content': '강아지가 사회화되는 행동의 사례는 뭐가 있을까?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 99
# Question: [{'role': 'user', 'content': '너 잘하는게 뭐야?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 100
# Question: [{'role': 'user', 'content': '지구에서 새로운 땅이 생겨나는 메커니즘은?'}]
# Answer:  퇴적은 새로운 땅을 형성하는 중요한 과정으로, 자연 현상으로서 강, 바다, 바람 등 다양한 요인에 의해 발생할 수 있습니다. 이러한 퇴적물은 새로운 토지를 형성하는 데 필수적인 재료로 사용되며, 시간이 지남에 따라 새로운 땅을 형성하고 지형을 변화시키는 역할을 합니다. 따라서 퇴적은 새로운 땅이 생겨나는 메커니즘 중 가장 핵심적인 역할을 합니다.
# Standalone Query: 새로운 땅 생성 메커니즘
# Is Science Related: False
#
# Test 101
# Question: [{'role': 'user', 'content': '더러워진 엔진오일을 잘 처리하는 방법에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 102
# Question: [{'role': 'user', 'content': '너 정말 똑똑하다!'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 103
# Question: [{'role': 'user', 'content': '다람쥐가 열매를 땅에 묻는 행동이 나무에 미치는 영향은?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 104
# Question: [{'role': 'user', 'content': '새로운 생명체의 발생에 대한 오래된 믿음을 깨기 위해 어떤 방법이 사용되었나?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 105
# Question: [{'role': 'user', 'content': '협곡이 형성되는 과정은?'}]
# Answer:  강물이 지형을 침식하여 계곡과 협곡을 형성합니다. 이는 강물의 강력한 힘과 자연의 영향력에 의해 일어납니다. 강은 계곡과 협곡을 형성하는 주요한 요소 중 하나입니다.
# Standalone Query: 협곡 형성 과정
# Is Science Related: True
#
# Test 106
# Question: [{'role': 'user', 'content': 'python 공부중인데...'}, {'role': 'assistant', 'content': '네 꼭 필요한 언어라서 공부해 두면 좋습니다.'}, {'role': 'user', 'content': '숫자 계산을 위한 operator 우선순위에 대해 알려줘.'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 107
# Question: [{'role': 'user', 'content': '지구상에 존재하는 물 중 가장 많은 물은 바닷물이잖아?'}, {'role': 'assistant', 'content': '네 맞습니다.'}, {'role': 'user', 'content': '바닷물 말고 담수가 가장 많이 있는 곳이 어디야?'}]
# Answer:  지구의 담수 대부분은 얼음으로 존재하며, 이는 지구의 극지방과 높은 산악 지대에서 발견됩니다. 또한, 높은 산악 지대에서는 눈과 빙하가 녹아서 하천과 강으로 흘러들어가는 물의 원천이 됩니다. 따라서, 얼음은 지구의 담수 공급과 생태계에 매우 중요한 자원입니다.
# Standalone Query: 지구상의 가장 많은 물은 어디에 존재하는가?
# Is Science Related: True
#
# Test 108
# Question: [{'role': 'user', 'content': '폭풍을 쫓는 사람들이 누구야?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 109
# Question: [{'role': 'user', 'content': '우라늄을 사용한 원자력 발전의 단점에 대해 알려줘.'}]
# Answer:  우라늄은 재생 불가능한 자원이며, 에너지로 사용될 때 지구의 하부시스템에 장기적으로 부정적인 영향을 미칠 수 있는 폐기물을 생성합니다. 이러한 폐기물은 환경 오염과 생태계 파괴에 영향을 줄 수 있으며, 긴 시간 동안 방사능을 유지하여 인체 건강에도 위험을 초래할 수 있습니다. 따라서 우라늄은 지구의 생태계와 인류의 건강에 부정적인 영향을 미칠 수 있는 가장 긴 시간 동안 폐기물을 생성하는 에너지원 중 하나입니다.
# Standalone Query: 우라늄 원자력 발전 단점
# Is Science Related: True
#
# Test 110
# Question: [{'role': 'user', 'content': '고체에서 액체로 변할 때 엔트로피는 어떻게 되나?'}]
# Answer:  고체에서 액체로 변할 때 엔트로피는 양적으로 증가합니다. 이는 분자 간의 상호작용이 늘어나고, 분자의 자유도가 증가하기 때문입니다. 따라서, 고체가 녹을 때는 엔트로피가 양적으로 변화하게 됩니다.
# Standalone Query: 고체에서 액체로 변할 때 엔트로피 변화
# Is Science Related: True
#
# Test 111
# Question: [{'role': 'user', 'content': '사회로부터의 감정적인 지원이 어떤 형태로 나타날 수 있어?'}]
# Answer:
# Standalone Query:
# Is Science Related: False
#
# Test 112
# Question: [{'role': 'user', 'content': '석탄을 에너지원으로 사용할 때의 장단점이 뭐야?'}]
# Answer:  석탄은 저렴하고 효율적인 에너지원이지만 생태계를 손상시키는 문제점이 있습니다. 이로 인해 대기 오염, 지하수 오염, 토양 침식 등의 문제가 발생할 수 있습니다. 따라서 친환경적인 재생에너지를 개발하고 보급하는 것이 중요합니다.
# Standalone Query: 석탄 에너지 장단점
# Is Science Related: True
#
# Test 113
# Question: [{'role': 'user', 'content': '탄소의 내부 구조를 알아낼 수 있는 방법은?'}]
# Answer:  탄소의 내부 구조를 알아낼 수 있는 방법은 다이아몬드와 유사한 특성을 가지는 탄화규소의 고체 상태 구조를 연구하는 것입니다. 이러한 구조는 탄소 원자들이 공유 결합을 형성하여 강력한 결합을 만들어내는 것으로 알려져 있으며, 이는 탄화규소가 다이아몬드와 함께 가장 단단한 물질 중 하나로 알려져 있는 이유입니다. 하지만 탄화규소는 불안정한 특성을 가지기 때문에 내부 구조를 알아내는 것은 어려운 과제일 수 있습니다.
# Standalone Query: 탄소 내부 구조 파악 방법
# Is Science Related: True
#
# Test 114
# Question: [{'role': 'user', 'content': '연구의 과정과 결과를 잘 기록해야 하는 이유?'}]
# Answer:  연구의 과정과 결과를 잘 기록하는 것은 다른 과학자들이 연구 결과를 검증하고 재현할 수 있으며, 연구 결과의 신뢰성을 높일 수 있기 때문입니다. 또한, 기록이 없다면 다른 과학자들은 해당 연구의 신뢰성을 의심하게 될 수 있습니다. 따라서, 과학자는 연구를 진행하면서 명확하고 체계적인 기록 관리를 유지하는 것이 매우 중요합니다.
# Standalone Query: 연구 기록의 중요성
# Is Science Related: False
#
# Test 115
# Question: [{'role': 'user', 'content': '니가 대답을 잘해줘서 기분이 좋아!'}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 eval_rag("/data/ephemeral/home/upstage-ai-final-ir2/upstage-ai-final-ir2/HM/data/eval.jsonl", "sample_submission_8.csv")
#
# Cell In[47], line 7, in eval_rag(eval_filename, output_filename)
#       5 j = json.loads(line)
#       6 print(f'Test {idx}\nQuestion: {j["msg"]}')
# ----> 7 response = answer_question(j["msg"])
#       8 print(f'Answer: {response["answer"]}')
#       9 print(f'Standalone Query: {response["standalone_query"]}')
#
# Cell In[46], line 3, in answer_question(query)
#       1 def answer_question(query):
#       2     # 과학 상식 관련 질문인지 확인
# ----> 3     if not is_science_related(query):
#       4         return {
#       5             "answer": "",
#       6             "standalone_query": "",
#    (...)
#       9             "references": []
#      10         }
#      13     # Standalone Query 생성
#
# Cell In[45], line 2, in is_science_related(query)
#       1 def is_science_related(query):
# ----> 2     science_check_result = science_check_chain.run(query).strip().lower()
#       3     return science_check_result == "true"
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain/chains/base.py:600, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     598     if len(args) != 1:
#     599         raise ValueError("`run` supports only one positional argument.")
# --> 600     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     601         _output_key
#     602     ]
#     604 if kwargs and not args:
#     605     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     606         _output_key
#     607     ]
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain/chains/base.py:383, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     351 """Execute the chain.
#     352
#     353 Args:
#    (...)
#     374         `Chain.output_keys`.
#     375 """
#     376 config = {
#     377     "callbacks": callbacks,
#     378     "tags": tags,
#     379     "metadata": metadata,
#     380     "run_name": run_name,
#     381 }
# --> 383 return self.invoke(
#     384     inputs,
#     385     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     386     return_only_outputs=return_only_outputs,
#     387     include_run_info=include_run_info,
#     388 )
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain/chains/base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain/chains/base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain/chains/llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain/chains/llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_core/language_models/llms.py:633, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     625 def generate_prompt(
#     626     self,
#     627     prompts: List[PromptValue],
#    (...)
#     630     **kwargs: Any,
#     631 ) -> LLMResult:
#     632     prompt_strings = [p.to_string() for p in prompts]
# --> 633     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_core/language_models/llms.py:803, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     788 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     789     run_managers = [
#     790         callback_manager.on_llm_start(
#     791             dumpd(self),
#    (...)
#     801         )
#     802     ]
# --> 803     output = self._generate_helper(
#     804         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805     )
#     806     return output
#     807 if len(missing_prompts) > 0:
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_core/language_models/llms.py:670, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668     for run_manager in run_managers:
#     669         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670     raise e
#     671 flattened_outputs = output.flatten()
#     672 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_core/language_models/llms.py:657, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     647 def _generate_helper(
#     648     self,
#     649     prompts: List[str],
#    (...)
#     653     **kwargs: Any,
#     654 ) -> LLMResult:
#     655     try:
#     656         output = (
# --> 657             self._generate(
#     658                 prompts,
#     659                 stop=stop,
#     660                 # TODO: support multiple run managers
#     661                 run_manager=run_managers[0] if run_managers else None,
#     662                 **kwargs,
#     663             )
#     664             if new_arg_supported
#     665             else self._generate(prompts, stop=stop)
#     666         )
#     667     except BaseException as e:
#     668         for run_manager in run_managers:
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_community/llms/openai.py:460, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     448     choices.append(
#     449         {
#     450             "text": generation.text,
#    (...)
#     457         }
#     458     )
#     459 else:
# --> 460     response = completion_with_retry(
#     461         self, prompt=_prompts, run_manager=run_manager, **params
#     462     )
#     463     if not isinstance(response, dict):
#     464         # V1 client returns the response in an PyDantic object instead of
#     465         # dict. For the transition period, we deep convert it to dict.
#     466         response = response.dict()
#
# File /root/home/envforir/lib/python3.10/site-packages/langchain_community/llms/openai.py:115, in completion_with_retry(llm, run_manager, **kwargs)
#     113 """Use tenacity to retry the completion call."""
#     114 if is_openai_v1():
# --> 115     return llm.client.create(**kwargs)
#     117 retry_decorator = _create_retry_decorator(llm, run_manager=run_manager)
#     119 @retry_decorator
#     120 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File /root/home/envforir/lib/python3.10/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File /root/home/envforir/lib/python3.10/site-packages/openai/resources/completions.py:528, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     499 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     500 def create(
#     501     self,
#    (...)
#     526     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     527 ) -> Completion | Stream[Completion]:
# --> 528     return self._post(
#     529         "/completions",
#     530         body=maybe_transform(
#     531             {
#     532                 "model": model,
#     533                 "prompt": prompt,
#     534                 "best_of": best_of,
#     535                 "echo": echo,
#     536                 "frequency_penalty": frequency_penalty,
#     537                 "logit_bias": logit_bias,
#     538                 "logprobs": logprobs,
#     539                 "max_tokens": max_tokens,
#     540                 "n": n,
#     541                 "presence_penalty": presence_penalty,
#     542                 "seed": seed,
#     543                 "stop": stop,
#     544                 "stream": stream,
#     545                 "stream_options": stream_options,
#     546                 "suffix": suffix,
#     547                 "temperature": temperature,
#     548                 "top_p": top_p,
#     549                 "user": user,
#     550             },
#     551             completion_create_params.CompletionCreateParams,
#     552         ),
#     553         options=make_request_options(
#     554             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     555         ),
#     556         cast_to=Completion,
#     557         stream=stream or False,
#     558         stream_cls=Stream[Completion],
#     559     )
#
# File /root/home/envforir/lib/python3.10/site-packages/openai/_base_client.py:1250, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1236 def post(
#    1237     self,
#    1238     path: str,
#    (...)
#    1245     stream_cls: type[_StreamT] | None = None,
#    1246 ) -> ResponseT | _StreamT:
#    1247     opts = FinalRequestOptions.construct(
#    1248         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1249     )
# -> 1250     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /root/home/envforir/lib/python3.10/site-packages/openai/_base_client.py:931, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     922 def request(
#     923     self,
#     924     cast_to: Type[ResponseT],
#    (...)
#     929     stream_cls: type[_StreamT] | None = None,
#     930 ) -> ResponseT | _StreamT:
# --> 931     return self._request(
#     932         cast_to=cast_to,
#     933         options=options,
#     934         stream=stream,
#     935         stream_cls=stream_cls,
#     936         remaining_retries=remaining_retries,
#     937     )
#
# File /root/home/envforir/lib/python3.10/site-packages/openai/_base_client.py:962, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     959 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     961 try:
# --> 962     response = self._client.send(
#     963         request,
#     964         stream=stream or self._should_stream_response_body(request=request),
#     965         **kwargs,
#     966     )
#     967 except httpx.TimeoutException as err:
#     968     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /root/home/envforir/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /root/home/envforir/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /root/home/envforir/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /root/home/envforir/lib/python3.10/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /root/home/envforir/lib/python3.10/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /root/home/envforir/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/conda/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /opt/conda/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
